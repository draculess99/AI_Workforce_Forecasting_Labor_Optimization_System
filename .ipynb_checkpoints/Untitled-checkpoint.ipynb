# %%
# !pip install -U google-genai
# Out:
# ...
#    ---------------------------------------- 0.0/783.6 kB ? eta -:--:--
#    ------------- -------------------------- 262.1/783.6 kB ? eta -:--:--
#    ---------------------------------------- 783.6/783.6 kB 2.5 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [websockets]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    ---------------------------------------- 2/2 [google-genai]
#
# ...

# %%
from google import genai

client = genai.Client(api_key="AIzaSyCehLTIw-Xm9LqFepsB2VJvpHHyDM7sPG4")

prompt = """
Forecast = 245000
Trend = Rising
Recommendation = VET
Savings = $4800

Explain in 3 business sentences for warehouse manager.
"""

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=prompt
)

print(response.text)
