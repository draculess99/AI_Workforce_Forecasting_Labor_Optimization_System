# %% [markdown]
# # Single step forecasting with machine learning
#
# [Forecasting with Machine Learning - Course](https://www.trainindata.com/p/forecasting-with-machine-learning)
#
# In this notebook, we will pick up the table of predictive features and a target from the first notebook and train a machine learning model to do forecasting.
#
# We will do **single step** ahead forecasting.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Lasso
from sklearn.metrics import root_mean_squared_error

# %% [markdown]
# # Load data
#
# We will use the electricity demand dataset found [here](https://github.com/tidyverts/tsibbledata/tree/master/data-raw/vic_elec/VIC2015).
#
# **Citation:**
#
# Godahewa, Rakshitha, Bergmeir, Christoph, Webb, Geoff, Hyndman, Rob, & Montero-Manso, Pablo. (2021). Australian Electricity Demand Dataset (Version 1) [Data set]. Zenodo. https://doi.org/10.5281/zenodo.4659727
#
# **Description of data:**
#
# A description of the data can be found [here](https://rdrr.io/cran/tsibbledata/man/vic_elec.html). The data contains electricity demand in Victoria, Australia, at 30 minute intervals over a period of 12 years, from 2002 to early 2015. There is also the temperature in Melbourne at 30 minute intervals and public holiday dates.

# %%
import pandas as pd

# 1. Load the data
train = pd.read_csv('train.csv')
features = pd.read_csv('features.csv')
stores = pd.read_csv('stores.csv')

# 2. Merge dataframes combines  sales (target), external factors (future use), store info
# Why: So the model has all context (Store size, Temperature, etc.) in one row.
df = train.merge(features, on=['Store', 'Date', 'IsHoliday'], how='left')
df = df.merge(stores, on=['Store'], how='left')

# %%
df.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  Fuel_Price  \
# 0      1     1  2010-02-05      24924.50      False        42.31       2.572
# 1      1     1  2010-02-12      46039.49       True        38.51       2.548
# 2      1     1  2010-02-19      41595.55      False        39.93       2.514
# 3      1     1  2010-02-26      19403.54      False        46.63       2.561
# 4      1     1  2010-03-05      21827.90      False        46.50       2.625
#
#    MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0        NaN        NaN        NaN        NaN        NaN  211.096358
# 1        NaN        NaN        NaN        NaN        NaN  211.242170
# 2        NaN        NaN        NaN        NaN        NaN  211.289143
# 3        NaN        NaN        NaN        NaN        NaN  211.319643
# 4        NaN        NaN        NaN        NaN        NaN  211.350143
#
#    Unemployment Type    Size
# 0         8.106    A  151315
# 1         8.106    A  151315
# 2         8.106    A  151315
# 3         8.106    A  151315
# 4         8.106    A  151315

# %%
#df['Date'] = pd.to_datetime(df['Date'])

# df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
#df = df.dropna(subset=['Date'])

#df_agg = df.reset_index(drop=True)   # remove fake 1970 index
df['Date'] = pd.to_datetime(df['Date'])  # use real dates

# 3. Set index
df = df.set_index('Date')

# 4. aggregated ALL stores into one time series earlier  and then created lag features on that aggregated data
df_agg = df.groupby(df.index)['Weekly_Sales'].sum().to_frame()

df_agg = df_agg.reset_index()
df_agg = df_agg.sort_index()

df = df_agg[['Date', 'Weekly_Sales']]

print(df.head())
# Out:
#         Date  Weekly_Sales
# 0 2010-02-05   49750740.50
# 1 2010-02-12   48336677.63
# 2 2010-02-19   48276993.78
# 3 2010-02-26   43968571.13
# 4 2010-03-05   46871470.30

# %%
print(df.tail())
# Out:
#           Date  Weekly_Sales
# 138 2012-09-28   43734899.40
# 139 2012-10-05   47566639.31
# 140 2012-10-12   46128514.25
# 141 2012-10-19   45122410.57
# 142 2012-10-26   45544116.29

# %% [markdown]
# ## Lag features
#
# We shift pass values of the time series forward. We discussed these 3 features in a previous notebook / video.

# %%
df[f"lag_1"] = df["Weekly_Sales"].shift(periods=1)

freq = "2"
df[f"lag_{freq}"] = df["Weekly_Sales"].shift(periods=2)

freq = "3"
df[f"lag_{freq}"] = df["Weekly_Sales"].shift(periods=3)

freq = "4"
df[f"lag_{freq}"] = df["Weekly_Sales"].shift(periods=4)

freq = "13"
df[f"lag_{freq}"] = df["Weekly_Sales"].shift(periods=13)

freq = "52"
df[f"lag_{freq}"] = df["Weekly_Sales"].shift(periods=52)
df.head()
# Out:
#         Date  Weekly_Sales        lag_1        lag_2        lag_3       lag_4  \
# 0 2010-02-05   49750740.50          NaN          NaN          NaN         NaN
# 1 2010-02-12   48336677.63  49750740.50          NaN          NaN         NaN
# 2 2010-02-19   48276993.78  48336677.63  49750740.50          NaN         NaN
# 3 2010-02-26   43968571.13  48276993.78  48336677.63  49750740.50         NaN
# 4 2010-03-05   46871470.30  43968571.13  48276993.78  48336677.63  49750740.5
#
#    lag_13  lag_52
# 0     NaN     NaN
# 1     NaN     NaN
# 2     NaN     NaN
# 3     NaN     NaN
# 4     NaN     NaN

# %% [markdown]
# ## Window features
#
# We aggregate values within windows in the past.  We discussed these windows in a previous notebook / video.

# %%
# We'll use a 4 and 13 window size.

result = (
    df["Weekly_Sales"]
    .rolling(window=4) # Pick window size.
    .agg(["mean","std"]) # Pick statistics.
    .shift(periods=1) # Lag by 1 week to avoid data leakage.
)  

result = result.add_prefix("rolling_4_")

# add features to main dataframe

df = df.merge(result, how="left", left_index=True, right_index=True)

# %%
# We'll use a 4 and 13 window size.

result = (
    df["Weekly_Sales"]
    .rolling(window=13) # Pick window size.
    .agg(["mean", "std"]) # Pick statistics.
    .shift(periods=1) # Lag by 1 week to avoid data leakage.
)  

result = result.add_prefix("rolling_13_")

# add features to main dataframe

df = df.merge(result, how="left", left_index=True, right_index=True)

import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)

#df.head(10)

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)


#df.head(10)

# %% [markdown]
# ## Datetime features
#
# We'll create date and time related features from the time series.

# %%
df["month"] = df['Date'].dt.month
df["day"] =df['Date'].dt.day
df["year"] = df['Date'].dt.year

df.head()
# Out:
#         Date  Weekly_Sales        lag_1        lag_2        lag_3       lag_4  lag_13  lag_52  rolling_4_mean  rolling_4_std  rolling_13_mean  rolling_13_std  month  day  year
# 0 2010-02-05   49750740.50          NaN          NaN          NaN         NaN     NaN     NaN             NaN            NaN              NaN             NaN      2    5  2010
# 1 2010-02-12   48336677.63  49750740.50          NaN          NaN         NaN     NaN     NaN             NaN            NaN              NaN             NaN      2   12  2010
# 2 2010-02-19   48276993.78  48336677.63  49750740.50          NaN         NaN     NaN     NaN             NaN            NaN              NaN             NaN      2   19  2010
# 3 2010-02-26   43968571.13  48276993.78  48336677.63  49750740.50         NaN     NaN     NaN             NaN            NaN              NaN             NaN      2   26  2010
# 4 2010-03-05   46871470.30  43968571.13  48276993.78  48336677.63  49750740.5     NaN     NaN     47583245.76   2.504187e+06              NaN             NaN      3    5  2010

# %% [markdown]
# ## Finalize tabularization

# %%
df.dropna(inplace=True)

y = df["Weekly_Sales"]
X = df.drop("Weekly_Sales", axis=1)

# Predictors
#X.head()

# %% [markdown]
# ## Lasso
#
# We'll split the data into train and test.
#
# We train the model on the train set and evaluate it on the test set.

# %%
print(df.columns)
# Out:
# Index(['Date', 'Weekly_Sales', 'lag_1', 'lag_2', 'lag_3', 'lag_4', 'lag_13', 'lag_52', 'rolling_4_mean', 'rolling_4_std', 'rolling_13_mean', 'rolling_13_std', 'month', 'day', 'year'], dtype='object')

# %%
df.head()
# Out:
#          Date  Weekly_Sales        lag_1        lag_2        lag_3        lag_4       lag_13       lag_52  rolling_4_mean  rolling_4_std  rolling_13_mean  rolling_13_std  month  day  year
# 52 2011-02-04   46153111.12  39599852.99  40654648.03  40673678.04  42775787.77  45781981.89  49750740.50    4.092599e+07   1.331375e+06     5.040907e+07    1.244825e+07      2    4  2011
# 53 2011-02-11   47336192.79  46153111.12  39599852.99  40654648.03  40673678.04  46124800.83  48336677.63    4.177032e+07   2.964632e+06     5.043762e+07    1.243717e+07      2   11  2011
# 54 2011-02-18   48716164.12  47336192.79  46153111.12  39599852.99  40654648.03  45125584.18  48276993.78    4.343595e+07   3.874968e+06     5.053080e+07    1.240667e+07      2   18  2011
# 55 2011-02-25   44125859.84  48716164.12  47336192.79  46153111.12  39599852.99  65821003.24  43968571.13    4.545133e+07   4.039147e+06     5.080700e+07    1.231594e+07      2   25  2011
# 56 2011-03-04   46980603.74  44125859.84  48716164.12  47336192.79  46153111.12  49909027.88  46871470.30    4.658283e+07   1.944225e+06     4.913814e+07    1.155855e+07      3    4  2011

# %%
#Add time features
# df.index = pd.to_datetime(df.index)
# df['week'] = df.index.isocalendar().week.astype(int)
# df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# df = df.dropna(subset=['Date'])

# Drop NaN
df = df.dropna()

df = df.reset_index(drop=True)

# %%
df
# Out:
#          Date  Weekly_Sales        lag_1        lag_2        lag_3        lag_4       lag_13       lag_52  rolling_4_mean  rolling_4_std  rolling_13_mean  rolling_13_std  month  day  year
# 0  2011-02-04   46153111.12  39599852.99  40654648.03  40673678.04  42775787.77  45781981.89  49750740.50    4.092599e+07   1.331375e+06     5.040907e+07    1.244825e+07      2    4  2011
# 1  2011-02-11   47336192.79  46153111.12  39599852.99  40654648.03  40673678.04  46124800.83  48336677.63    4.177032e+07   2.964632e+06     5.043762e+07    1.243717e+07      2   11  2011
# 2  2011-02-18   48716164.12  47336192.79  46153111.12  39599852.99  40654648.03  45125584.18  48276993.78    4.343595e+07   3.874968e+06     5.053080e+07    1.240667e+07      2   18  2011
# 3  2011-02-25   44125859.84  48716164.12  47336192.79  46153111.12  39599852.99  65821003.24  43968571.13    4.545133e+07   4.039147e+06     5.080700e+07    1.231594e+07      2   25  2011
# 4  2011-03-04   46980603.74  44125859.84  48716164.12  47336192.79  46153111.12  49909027.88  46871470.30    4.658283e+07   1.944225e+06     4.913814e+07    1.155855e+07      3    4  2011
# ..        ...           ...          ...          ...          ...          ...          ...          ...             ...            ...              ...             ...    ...  ...   ...
# 86 2012-09-28   43734899.40  44354547.11  44226038.65  48330059.31  47159639.43  46597112.12  42195830.81    4.601757e+07   2.051598e+06     4.675908e+07    1.932826e+06      9   28  2012
# 87 2012-10-05   47566639.31  43734899.40  44354547.11  44226038.65  48330059.31  51253021.88  47211688.36    4.516139e+07   2.129258e+06     4.653890e+07    2.107903e+06     10    5  2012
# 88 2012-10-12   46128514.25  47566639.31  43734899.40  44354547.11  44226038.65  46099732.10  44374820.30    4.497053e+07   1.751216e+06     4.625534e+07    1.610048e+06     10   12  2012
# 89 2012-10-19   45122410.57  46128514.25  47566639.31  43734899.40  44354547.11  46059543.45  45818953.44    4.544615e+07   1.739930e+06     4.625755e+07    1.609836e+06     10   19  2012
# 90 2012-10-26   45544116.29  45122410.57  46128514.25  47566639.31  43734899.40  44097154.97  45855821.05    4.563812e+07   1.617393e+06     4.618546e+07    1.640138e+06     10   26  2012
#
# [91 rows x 15 columns]

# %%
# df['Date'] = pd.to_datetime(df['Date'])
# df = df.sort_values('Date')
df = df.set_index('Date')  

# Split
split_date = '2012-01-01'

# %%
train = df[df.index < split_date]
test  = df[df.index >= split_date]

# %%
features = ['lag_1', 'lag_2','lag_3', 'lag_4', 'lag_13', 'lag_52', 'rolling_4_mean', 'rolling_4_std', 'rolling_13_mean', 'rolling_13_std', 'month', 'day', 'year']

X_train = train[features]
y_train = train['Weekly_Sales']

X_test = test[features]
y_test = test['Weekly_Sales']

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test  = scaler.transform(X_test)

X_train = pd.DataFrame(X_train, 
                       columns=features, 
                       index=train.index)

X_test = pd.DataFrame(X_test, 
                      columns=features, 
                      index=test.index)

# %%
#print(df['Date'].min(), df['Date'].max())

# %%
X_train.head()
# Out:
#                lag_1     lag_2     lag_3     lag_4    lag_13    lag_52  rolling_4_mean  rolling_4_std  rolling_13_mean  rolling_13_std     month       day  year
# Date
# 2011-02-04 -1.298708 -1.393361 -1.419397 -0.867029 -0.188103  0.315638       -1.628518      -0.490613         2.027684        2.152769 -1.611413 -1.286228   0.0
# 2011-02-11 -0.215857 -1.636383 -1.424200 -1.426840 -0.137175  0.099561       -1.387152       0.173384         2.043075        2.149915 -1.611413 -0.491793   0.0
# 2011-02-18 -0.020366 -0.126529 -1.690402 -1.431908 -0.285617  0.090441       -0.911006       0.543478         2.093309        2.142053 -1.611413  0.302642   0.0
# 2011-02-25  0.207658  0.146050 -0.036534 -1.712809  2.788868 -0.567912       -0.334877       0.610225         2.242206        2.118670 -1.611413  1.097077   0.0
# 2011-03-04 -0.550837  0.463992  0.262045  0.032384  0.425005 -0.124332       -0.011419      -0.241460         1.342537        1.923464 -1.294413 -1.286228   0.0

# %%
X_test.head()
# Out:
#                lag_1     lag_2     lag_3     lag_4    lag_13    lag_52  rolling_4_mean  rolling_4_std  rolling_13_mean  rolling_13_std     month       day  year
# Date
# 2012-01-06 -0.234141  6.980111  3.479682  2.537830  0.024292 -0.750176        3.730296       4.232520         3.113495        1.486619 -1.928412 -1.059247   1.0
# 2012-01-13 -0.413762 -0.152023  7.747960  3.742759 -0.397149 -1.071391        2.972342       5.064473         3.019930        1.517156 -1.928412 -0.264812   1.0
# 2012-01-20 -0.898298 -0.402474 -0.064459  8.246724 -0.182611 -1.074299        1.681470       5.642393         2.922407        1.562103 -1.928412  0.529623   1.0
# 2012-01-27 -0.888728 -1.078078 -0.338799  0.002916 -0.177134 -1.235478       -0.813943      -0.202893         2.767399        1.624401 -1.928412  1.324058   1.0
# 2012-02-03 -1.259857 -1.064734 -1.078844 -0.286572  0.238789 -0.234101       -1.257571      -0.178165         2.517722        1.730547 -1.611413 -1.399719   1.0

# %%
lasso = Lasso(alpha=0.01, max_iter=10000, random_state=9)

lasso.fit(X_train, y_train)

preds = lasso.predict(X_test)
preds = pd.Series(preds, index=y_test.index)

#preds = lasso.predict(X_test)

rmse = root_mean_squared_error(y_test, preds)

print(f"performance of lasso = {np.round(rmse, 0)}")
# Out:
# performance of lasso = 4263821.0
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.866e+11, tolerance: 1.697e+11
#   model = cd_fast.enet_coordinate_descent(

# %%
#df

# %%
fig, ax = plt.subplots(figsize=(12,5))

import matplotlib.ticker as mtick
plt.gca().yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

ax.plot(y_train.index[-100:], y_train[-100:], label='Train')
ax.plot(y_test.index, y_test, label='Test')
ax.plot(preds.index, preds, label='LASSO Prediction')

ax.set_title("LASSO Forecast (Aggregated)")
ax.set_xlabel("Date")
ax.set_ylabel("Weekly Sales")

ax.legend()
ax.grid()

#ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
seasonal_naive_full = df['Weekly_Sales'].shift(52)

# then align with test index
seasonal_naive_pred = seasonal_naive_full.loc[y_test.index]

# %%
fig, ax = plt.subplots(figsize=(12,5))

ax.plot(y_train.index[-100:], y_train[-100:], label='Train')
ax.plot(y_test.index, y_test, label='Test')
ax.plot(preds.index, preds, label='LASSO Prediction')

predscmp_lasso=preds

import matplotlib.ticker as mtick
plt.gca().yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

# NEW: Baselines
ax.plot(y_test.index, seasonal_naive_pred.values,
        label='seasonal Naive ', linestyle='--', color='black')

# Labels
ax.set_title("LASSO vs Baselines (Aggregated)")
ax.set_xlabel("Date")
ax.set_ylabel("Weekly Sales")

ax.legend()
ax.grid()

#ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# The data was aggregated across all stores to create a single time series, and a univariate forecasting problem was modeled using lag-based features
# The model is a global univariate forecasting model using lag and rolling window features derived from historical sales.

# %%
train.head()
# Out:
#             Weekly_Sales        lag_1        lag_2        lag_3        lag_4       lag_13       lag_52  rolling_4_mean  rolling_4_std  rolling_13_mean  rolling_13_std  month  day  year
# Date
# 2011-02-04   46153111.12  39599852.99  40654648.03  40673678.04  42775787.77  45781981.89  49750740.50    4.092599e+07   1.331375e+06     5.040907e+07    1.244825e+07      2    4  2011
# 2011-02-11   47336192.79  46153111.12  39599852.99  40654648.03  40673678.04  46124800.83  48336677.63    4.177032e+07   2.964632e+06     5.043762e+07    1.243717e+07      2   11  2011
# 2011-02-18   48716164.12  47336192.79  46153111.12  39599852.99  40654648.03  45125584.18  48276993.78    4.343595e+07   3.874968e+06     5.053080e+07    1.240667e+07      2   18  2011
# 2011-02-25   44125859.84  48716164.12  47336192.79  46153111.12  39599852.99  65821003.24  43968571.13    4.545133e+07   4.039147e+06     5.080700e+07    1.231594e+07      2   25  2011
# 2011-03-04   46980603.74  44125859.84  48716164.12  47336192.79  46153111.12  49909027.88  46871470.30    4.658283e+07   1.944225e+06     4.913814e+07    1.155855e+07      3    4  2011

# %% [markdown]
# The data was aggregated to a single time series to ensure one observation per date, enabling proper forecasting and visualization.”

# %%
# We can also understand what is driving the predictions of this
# lasso regression.

importance = lasso.coef_
features = lasso.feature_names_in_

pd.Series(importance, index=features).sort_values(ascending=False).plot.bar()
plt.title("Feature importance")
plt.ylabel("Coefficient value")
# Out:
# Text(0, 0.5, 'Coefficient value')

# %% [markdown]
# The hour and the day are the most important predictors of energy consumption.

# %% [markdown]
# ## Random forest

# %%
rf = RandomForestRegressor(n_estimators=10, random_state=9)

rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=9)

# %%
preds = rf.predict(X_test)

rmse = root_mean_squared_error(y_test, preds)

print(f"performance of random forests = {np.round(rmse, 0)}")
# Out:
# performance of random forests = 2133019.0

# %% [markdown]
# These results are even better than those from Lasso!

# %%
# convert to series for plotting
preds = pd.Series(preds, index=X_test.index)
preds.head()
# Out:
# Date
# 2012-01-06    4.575305e+07
# 2012-01-13    4.549316e+07
# 2012-01-20    4.451849e+07
# 2012-01-27    4.526197e+07
# 2012-02-03    4.634988e+07
# dtype: float64

# %%
seasonal_naive_full = df['Weekly_Sales'].shift(52)

# then align with test index
seasonal_naive_pred = seasonal_naive_full.loc[y_test.index]

# %%
# plot predictions vs actuals

fig, ax = plt.subplots(figsize=(12, 5))

import matplotlib.ticker as mtick
plt.gca().yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

ax.plot(y_train.index[-100:], y_train[-100:], label='Train')
ax.plot(y_test.index, y_test, label='Test')
ax.plot(preds.index, preds, label='Random Forrest Prediction')

predscmp_regresstree=preds

# NEW: Baselines
ax.plot(y_test.index, seasonal_naive_pred.values,
        label='seasonal Naive ', linestyle='--', color='black')

# Labels
ax.set_title("Random Trees vs Baselines (Aggregated)")
ax.set_xlabel("Date")
ax.set_ylabel("Weekly Sales")

ax.legend(bbox_to_anchor=(1.3, 1.0));

# %%
importance = rf.feature_importances_
features = rf.feature_names_in_

pd.Series(importance, index=features).sort_values(ascending=False).plot.bar()
plt.title("Feature importance")
plt.ylabel("Feature importance")
# Out:
# Text(0, 0.5, 'Feature importance')

# %% [markdown]
# For the random forests, the energy consumption in the previews hour, seems to be the most important feature to predict demand.

# %% [markdown]
# <h3> Gradient Boost Regression model</h3>

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
from xgboost import XGBRegressor

for depth in [3, 4, 5, 6, 8]:
    xgb = XGBRegressor(
        n_estimators=500,
        max_depth=depth,
        learning_rate=0.03,
        subsample=0.8,
        colsample_bytree=0.8,
        min_child_weight=3,
        gamma=0.1,
        reg_alpha=0.1,
        reg_lambda=1.0,
        random_state=9
    )

    xgb.fit(X_train, y_train)
    preds = xgb.predict(X_test)
    
    rmse = np.sqrt(mean_squared_error(y_test, preds))
    print(f"Depth {depth} RMSE:", round(rmse, 0))
# Out:
# Depth 3 RMSE: 2050086.0
# Depth 4 RMSE: 2028904.0
# Depth 5 RMSE: 2077703.0
# Depth 6 RMSE: 2116667.0
# Depth 8 RMSE: 2138948.0

# %%
from xgboost import XGBRegressor

xgb = XGBRegressor(
        n_estimators=500,
        max_depth=4,
        learning_rate=0.03,
        subsample=0.8,
        colsample_bytree=0.8,
        min_child_weight=3,
        gamma=0.1,
        reg_alpha=0.1,
        reg_lambda=1.0,
        random_state=9
)

# %%
xgb.fit(X_train, y_train)
preds = xgb.predict(X_test)

# %%
# convert to series for plotting
preds = pd.Series(preds, index=X_test.index)
preds.head()
# Out:
# Date
# 2012-01-06    43569772.0
# 2012-01-13    42774320.0
# 2012-01-20    43279780.0
# 2012-01-27    42646492.0
# 2012-02-03    46473892.0
# dtype: float32

# %%
seasonal_naive_full = df['Weekly_Sales'].shift(52)

# then align with test index
seasonal_naive_pred = seasonal_naive_full.loc[y_test.index]

# %%
# plot predictions vs actuals

fig, ax = plt.subplots(figsize=(12, 5))

import matplotlib.ticker as mtick
plt.gca().yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

ax.plot(y_train.index[-100:], y_train[-100:], label='Train')
ax.plot(y_test.index, y_test, label='Test')
ax.plot(preds.index, preds, label='XGBoost Prediction')

predscmp_xgboosttree=preds


# NEW: Baselines
ax.plot(y_test.index, seasonal_naive_pred.values,
        label='seasonal Naive ', linestyle='--', color='black')

# Labels
ax.set_title("XGBoost vs Baselines (Aggregated)")
ax.set_xlabel("Date")
ax.set_ylabel("Weekly Sales")

ax.legend(bbox_to_anchor=(1.3, 1.0));

# %%
# plot predictions vs actuals

fig, ax = plt.subplots(figsize=(22, 12))

import matplotlib.ticker as mtick
plt.gca().yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

ax.plot(y_train.index[-2:], y_train[-2:], label='Train')
ax.plot(y_test.index, y_test, label='Test')
ax.plot(preds.index, preds, label='XGBoost Prediction')

# NEW: Baselines
ax.plot(y_test.index, seasonal_naive_pred.values,
        label='seasonal Naive ', linestyle='--', color='black')
ax.plot(y_test.index, predscmp_regresstree.values,
       label='regression tree ', linestyle='--', color='yellow')

# Labels
ax.set_title("XGBoost vs Baselines (Aggregated)")
ax.set_xlabel("Date")
ax.set_ylabel("Weekly Sales")

ax.set_ylim(40_000_000, 53_000_000)

ax.legend(bbox_to_anchor=(1.3, 1.0));
