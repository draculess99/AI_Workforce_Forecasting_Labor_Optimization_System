# %%
import sys
print(sys.executable)
# Out:
# C:\ProgramData\anaconda3\python.exe

# %%
import os
os.getcwd()
# Out:
# 'D:\\Work\\Springboard\\CAPSTONE-Final - LangChain - sixth RAG\\TraininData\\WORKTRAIN\\WalmartBenchmark'

# %%
# !pip freeze > versions.txt

# %%
pip install jupytext
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !jupytext --to notebook streamlit_app.py
# Out:
# [jupytext] Reading streamlit_app.py in format py
# [jupytext] Writing streamlit_app.ipynb

# %%
os.chdir("D:\Work\Springboard\CAPSTONE-Final\TraininData\WORKTRAIN\WalmartBenchmark")

# %%
# !pip install -q -U google-generativeai

# %%
# !pip install groq

# %%
# !jupyter nbconvert --to script VET_VTO_Forecaster2.ipynb

# %%
# !jupyter nbconvert --to script streamlit_app.ipynb

# %%
pip install streamlit
